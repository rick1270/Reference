# %% [markdown]
# <a href="https://colab.research.google.com/github/rick1270/Reference/blob/master/Google_Map_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen
from PIL import Image
api_key = input('What is your Google API Key?: ') or 'AIzaSyCKWAh0peH2KSimm69QmtOWYmje1kPYPlY'
endpoint = 'https://maps.googleapis.com/maps/api/staticmap?'
center = (input('Where should the center point of the map be?: ').replace(' ', '+')) or 'San+Diego,+California'
zoom = (input('What zoom should be used (0 to 23)?: ').replace(' ', '+')) or 6
height = ((input('How tall should the map be (Kilometers)?: ').replace(' ', '+'))) or 1000
width = ((input('How wide should the map be (Kilometers)?: ').replace(' ', '+'))) or 1000
map_type = (input('What kind of map? (roadmap, satellite, hybrid, terrain): ').replace(' ', '+')) or 'hybrid'
map_url = str(endpoint) + 'center=' + str(center) + '&zoom=' + str(zoom) + '&size=' + str(width) + 'x' + str(height) + '&maptype=' + str(map_type) + '&key=' + str(api_key)
img = Image.open(urlopen(map_url))
img
# Out:
# What is your Google API Key?: AIzaSyCKWAh0peH2KSimm69QmtOWYmje1kPYPlY
# Where should the center point of the map be?: Austin, TX
# What zoom should be used (0 to 23)?: 6
# How tall should the map be (Kilometers)?: 2000
# How wide should the map be (Kilometers)?: 2000
# What kind of map? (roadmap, satellite, hybrid, terrain): hybrid
# <PIL.PngImagePlugin.PngImageFile image mode=P size=640x640 at 0x7FE790A52860>
